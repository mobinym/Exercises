# %% [markdown]
# <a href="https://colab.research.google.com/github/mobinym/Projects/blob/main/ASR_PROJECT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow keras librosa numpy

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import librosa
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from concurrent.futures import ThreadPoolExecutor

# %%
# تابع استخراج ویژگی‌ها
def extract_features(file_name):
    audio, sample_rate = librosa.load(file_name, sr=22050)
    mfccs = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=13)
    return np.mean(mfccs.T, axis=0)

# %%
audio_path = '/content/drive/MyDrive/DataSets/myaudio'
text_path = '/content/drive/MyDrive/DataSets/myaudio_tiny.xlsx'  # فایل CSV که شامل نام فایل‌های صوتی و متن آنهاست

# %%
# خواندن فایل‌های صوتی و متنی
df = pd.read_excel(text_path)

audio_files = [os.path.join(audio_path, f).replace('/myaudio/myaudio/', '/myaudio/') for f in df['audio']]
texts = df['text']

# # استخراج ویژگی‌ها و برچسب‌ها
# features = np.array([extract_features(f) for f in audio_files])
# print("Features:", features)
# print("Labels:", labels)

# استخراج ویژگی‌ها به صورت موازی
with ThreadPoolExecutor() as executor:
    features = list(executor.map(extract_features, audio_files))

features = pd.DataFrame(features)
labels = texts.tolist()
features.info()
features.describe()
# چاپ ویژگی‌ها و برچسب‌ها
print("Features:", features)
print("Labels:", labels)


# تبدیل برچسب‌ها به مقادیر عددی
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer(char_level=True)
tokenizer.fit_on_texts(labels)
sequences = tokenizer.texts_to_sequences(labels)
max_sequence_length = max([len(seq) for seq in sequences])
X_train = pad_sequences(sequences, maxlen=max_sequence_length)
X_train.shape
# نمایش شکل داده‌ها
print("Features shape: ", features.shape)
print('X_train',X_train.shape)
X_train = np.argmax(X_train, axis=1)
print('X_train',X_train.shape)
print("Labels shape: ", X_train.shape)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1082 entries, 0 to 1081
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       1082 non-null   float32
#  1   1       1082 non-null   float32
#  2   2       1082 non-null   float32
#  3   3       1082 non-null   float32
#  4   4       1082 non-null   float32
#  5   5       1082 non-null   float32
#  6   6       1082 non-null   float32
#  7   7       1082 non-null   float32
#  8   8       1082 non-null   float32
#  9   9       1082 non-null   float32
#  10  10      1082 non-null   float32
#  11  11      1082 non-null   float32
#  12  12      1082 non-null   float32
# dtypes: float32(13)
# memory usage: 55.1 KB
# Features:               0           1          2          3          4          5   \
# 0    -231.467545   98.935799  -0.679422  45.096607 -25.350702   7.527362
# 1    -181.159988  109.042076  -6.698942  53.532154 -32.726776   6.603848
# 2    -238.634201   92.140923   5.017074  48.673630 -21.840036  10.117661
# 3    -196.519852  114.561775  -5.269718  52.974838 -17.549456   5.079241
# 4    -241.962326  106.536667  -7.208020  47.241222 -24.566420   8.997882
# ...          ...         ...        ...        ...        ...        ...
# 1077 -319.268066   70.328209 -44.712788  65.869095 -24.493473  19.519300
# 1078 -293.757843   74.454628 -35.914482  57.735378 -30.107243  23.757542
# 1079 -295.634003   84.817535 -41.062267  59.804836 -22.291313  19.296696
# 1080 -308.052216   71.799667 -38.996593  50.664970 -25.324694  18.869087
# 1081 -295.070404   82.667480 -43.379948  50.180656 -25.358446  19.037148
#
#              6          7          8          9          10         11  \
# 0    -10.213285   5.600861  -5.723683   2.575464   1.381827  -1.238053
# 1    -11.596677   4.675699  -9.238749   2.987743   2.019859  -0.440416
# 2     -9.268249   7.752429  -5.270911  -1.126907   4.096147  -0.353693
# 3    -13.996313  -2.662068 -10.112541   1.750543  -1.816671  -0.938059
# 4    -10.836725   4.181168  -6.704568   4.671060  -0.220992  -2.128864
# ...         ...        ...        ...        ...        ...        ...
# 1077 -19.122297  -7.866881 -15.444475 -10.673668 -15.394137 -13.978315
# 1078 -24.693239 -12.789664 -21.153795  -8.978079 -18.556250 -17.322159
# 1079 -21.743204 -12.648063 -19.289442  -9.540794 -19.367912 -13.433455
# 1080 -19.635712 -10.331897 -18.420225 -11.397068 -19.405771 -12.508648
# 1081 -14.215076  -9.683423 -15.189863  -9.314837 -17.727793 -13.287176
#
#              12
# 0      4.556212
# 1      2.493119
# 2      1.047189
# 3      1.620007
# 4      3.570997
# ...         ...
# 1077 -10.344250
# 1078  -9.535446
# 1079  -9.674106
# 1080  -6.724477
# 1081 -14.941944
#
# [1082 rows x 13 columns]
# Labels: ['به نام خدا درسی رو که در خدمت شما خواهیم بود آموزش نرم افزار لتک هست', 'در واقع کار کردن با لتک و ایجاد مستندات و متن های فارسی', 'انگلیسی و کلا مستندات علمی هدف این است که تا جایی که', 'که ممکنه مطالبی رو که بیشتر کارایی داره براتون به دردتون می خوره در طول این ترم', 'آموزش داده بشه و یه مجموعه ی خوبی در اختیار شما قرار بگیره', 'کتابی رو نوشته بود در زمینه ی در زمینه ی رشته ی علوم کامپیوتر ولی متاسفانه سیستم حروفچینی مناسبی وجود', 'لایسنس اش در اختیار انجمن ریاضی آمریکاست و شما مجازید اون رو استفاده کنید کپی کنید تکثیر کنید', 'در اختیار هر کسی خواستید قرار بدید بدون اینکه هیچ هزینه ایی بابت اش نیاز به پرداخت باشه فقط حق فروش اش طبیعتاً کسی', 'نداره یعنی کسی از فروش نرم افزار حق کسب درآمد نداریم لتک', 'و تونست یه مجموعه ی جدیدی ایجاد بکنه که به کمک اون امکان', 'تهیه ی مستندات علمی و معمولی وجود داشت با یک سری قابلیت های بیشتر از تک و البته یه مقدار', 'ساده تر هم شد کار بسته های متنوعی بهش اضافه شد و خیلی ساده تر شد کار', 'لتک مورد استفاده اش هر چیزی ایست که جنبه ی نوشتاری پیدا بکند شما می تونید باهاش', 'متن معمولی بنویسید کتاب بنویسید می تونید مقاله بنویسید می تونید گزارش بنویسید پایان نامه بنویسید', 'و هر چیزی که شما می خواید تولید بکنید که نیاز به نوشتن داشته باشه طبیعتا لتک میتونه به کمک ما بیاید', 'اسلاید ما میتونینم تهیه بکنیم مثل همین اسلایدهایی که الان مشاهده می کنید اینا دقیقا با لتک ایجاد شده و با استفاده از', 'سبک بیمر تولید شده تماما اما واقعیتی که هست اینه که لتک محبوبیت بیشتری در بین', 'دانشگاهیان دارد به ویژه رشته های علوم پایه و مهندسی', 'زیباتر هست و حالا یه ویژگی هایی دیگری هم داره که سر موقع خودش راجع بهش صحبت', 'خواهیم کرد به همین دلیل میگم متن هایی که درش فرمول زیادی وجود داشته باشه بیشتر مورد علاقه هست که با لتک کار بشه', 'اما سوالی که پیش میاد اینه که خب در بین سیستم های حروف چینی', 'یا نرم افزار هایی که میشه باهاش حروف چینی انجام داد یک دسته نرم افزارا هستند مثل مجموعه ی آفیس', 'سوال اینه که کار کردن علیرغم اینکه با این نرم افزارها بسیار ساده تر هست ولی چرا', 'ما خودمون رو مجاب به این می کنیم که بریم سختی رو بپذیریم لتک رو یاد بگیریم', 'و متن های خودمون رو با استفاده از لتک تولید کنیم چه رازی در این نهفته است میایم میگیم', 'اولین ایراد اش که حالا شاید بزرگترین اش هم باشه اینه که اونا اون اولی مایکروسافت آفیس رایگان نیست', 'شما اگر بخواید استفاده بکنید یا باید نقض کپی رایت بکنید یا باید پول بدید و اون رو بخرید و از همه مهمتر اینکه', 'خروجی که لتک برای شما تولید میکنه به مراتب زیباتر و جذابتر هست از', 'حالا دلایلی این که ما از لتک استفاده می کنیم رو من چند تاش رو این جا آوردم', 'اما در لتک اینجوری نیست در لتک شما متن رو اگر توانستید با یک سیستم', 'با یک کامپیوتر تولید بکنید به درستی و بدون خطا این متن شما با هر کامپیوتر دیگری که', 'دوم این که کیفیت بسیار بالایی ما در حروفچینی متون ریاضی داریم در لتک', 'که این کیفیت هرگز در ورد قابل مشاهده نیست به عنوان نمونه و یه', 'ایجاد انگیزه من بیام دو تا نمونه به شما نشون بدم', 'این رو هم نگاه می کنیم به عنوان یه نمونه ی دیگه', 'اینا رو هر دو رو من بیام کنار هم قرار بدم ببینید این رو من بیام این ور بذارمش', 'شما اگر نگاه بکنید متن سمت چپ این متن با استفاده از ورد تولید شده', 'متن سمت راست با استفاده از لتک ایجاد شده به عنوان مثال شما این ماتریسی که این سمت تولید شده رو اگر نگاه بکنید', 'با همون ماتریس که در این سمت تولید شده اگر مقایسه بکنید خب می بینید کاملاً تفاوت رو می تونید احساس بکنید', 'یا انتگرالی که اینجا ایجاد شده با انتگرالی که اینجا ایجاد شده یا حدی که اینجا ایجاد شده حدی که اینجا ایجاد شده', 'و بقیه ی مواردی که وجود داره کیفیت خروجی بسیار متفاوت است', 'مشکل نمایش خاصی نداره اما کیفیت فرمول ها خیلی با هم فرق میکنه', 'پس در واقع دلیل اصلی که ما به این سمت رو میاریم و لتک رو سعی می کنیم یاد بگیریم', 'همین ماجرا هست که کیفیت بسیار بالایی رو ما در حروف چینی فرمول های ریاضی خواهیم داشت', 'اگر شما با ورد مایکروسافت افیس بخواید یک فایل بزرگی مثل کتاب تولید بکنید', 'اما در لتک این شکلی نیست شما برای اینکه یک کتاب تولید بکنید فقط کافیه از استایل بوک استفاده بکنید', 'فونت ها اندازه ی فونت ها همه چی در اختیار خود لتک خواهد بود و خیلی راحت کار میکنه', 'سومین دلیل این است که متعلقات نوشتاری مربوط به متن در لتک', 'یعنی فقط کافیه ما تک دستورهای لازم رو به کار بب ...
# Features shape:  (1082, 13)
# X_train (1082, 137)
# X_train (1082,)
# Labels shape:  (1082,)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Bidirectional, Embedding

# تغییر شکل داده‌ها برای ورودی به مدل
features = np.expand_dims(features, axis=1)
features.shape
# ساخت مدل
model = Sequential()
model.add(Bidirectional(LSTM(128, return_sequences=True), input_shape=(features.shape[1], features.shape[2])))
model.add(Bidirectional(LSTM(128)))
model.add(Dense(len(tokenizer.word_index) + 1, activation='softmax'))

# کامپایل کردن مدل
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# آموزش مدل
model.fit(features, X_train, epochs=10, batch_size=32, validation_split=0.2)

#---------------------------------------------------------------------------------------------------------------
# Out:
# Epoch 1/10
# 28/28 [==============================] - 38s 57ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 2/10
# 28/28 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 3/10
# 28/28 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 4/10
# 28/28 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 5/10
# 28/28 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 6/10
# 28/28 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 7/10
# 28/28 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 8/10
# 28/28 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 9/10
# 28/28 [==============================] - 0s 10ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 10/10
# 28/28 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00

# %%
import numpy as np

def normalize_features(features):
    mean = np.mean(features, axis=0)
    std = np.std(features, axis=0)
    normalized_features = (features - mean) / std
    return normalized_features

def predict_text(audio_file):
    feature = extract_features(audio_file)
    feature = normalize_features(feature)  # نرمال‌سازی ویژگی‌ها
    feature = np.expand_dims(feature, axis=0)
    feature = np.expand_dims(feature, axis=1)  # تغییر محور به 1 به جای 2

    # چاپ ویژگی‌های صوتی
    print("Extracted Features: ", feature)

    # پیش‌بینی با مدل
    prediction = model.predict(feature)

    # چاپ پیش‌بینی خام مدل
    print("Raw Prediction: ", prediction)

    # بررسی مقادیر NaN در پیش‌بینی
    if np.isnan(prediction).any():
        print("Prediction contains NaN values. Please check the model and input features.")
        return ""

    # تبدیل پیش‌بینی به متن
    predicted_sequence = np.argmax(prediction, axis=1)
    predicted_text = tokenizer.sequences_to_texts([predicted_sequence])

    return predicted_text[0]

# آزمایش مدل با یک فایل صوتی
test_audio_file = '/content/12560177.wav'
predicted_text = predict_text(test_audio_file)
print("Predicted Text: ", predicted_text)
# Out:
# Extracted Features:  [[[-3.1818354   1.4371285  -0.16468741  0.73870456  0.09384083
#     0.34663373  0.04638166  0.1747061   0.0812481   0.1664555
#     0.04077761  0.19929023  0.02135559]]]
# 1/1 [==============================] - 2s 2s/step
# Raw Prediction:  [[nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#   nan nan]]
# Prediction contains NaN values. Please check the model and input features.
# Predicted Text:
